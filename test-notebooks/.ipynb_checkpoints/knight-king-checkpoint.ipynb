# %%
import numpy as np 
from scipy import misc
from scipy.misc import imsave

# %%
f = misc.face()
# misc.imsave('face.png', f) # uses the Image module (PIL)

import matplotlib.pyplot as plt
plt.imshow(f)
plt.show()
# Out:
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.

# %%
face = misc.face()
misc.imsave('face.png', face) # First we need to create the PNG file

face = misc.imread('face.png')
type(face)      

face.shape, face.dtype
# Out:
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   after removing the cwd from sys.path.
# ((768, 1024, 3), dtype('uint8'))

# %%
face.tofile('face.raw') # Create raw file
face_from_raw = np.fromfile('face.raw', dtype=np.uint8)
face_from_raw.shape

face_from_raw.shape = (768, 1024, 3)

# %% [markdown]
# ## Displaying images

# %%
f = misc.face(gray=True)  # retrieve a grayscale image
import matplotlib.pyplot as plt
plt.imshow(f, cmap=plt.cm.gray)

# %%
# Increase contrast by setting min and max values
plt.imshow(f, cmap=plt.cm.gray, vmin=30, vmax=200)        

# Remove axes and ticks
plt.axis('off')
# Out:
# (-0.5, 1023.5, 767.5, -0.5)

# %%
# Draw contour lines
plt.contour(f, [50, 200])

# %% [markdown]
# ### For smooth intensity variations, use interpolation='bilinear'. For fine inspection of intensity variations, use interpolation='nearest'

# %%
plt.imshow(f[320:340, 510:530], cmap=plt.cm.gray, interpolation='bilinear')        

plt.imshow(f[320:340, 510:530], cmap=plt.cm.gray, interpolation='nearest')

# %% [markdown]
# ## Numpy Manipulations

# %%
# create face. Gray set to false
face = misc.face(gray=False)
# display regular 2-D raster
plt.imshow(face)

plt.show()

# %%
# shape
face.shape
# Out:
# (768, 1024, 3)

# %%
# Slicing
face[10:14, 20:23].shape
# Out:
# (4, 3, 3)

# %%
# print first value of shape
face.shape[0]
# Out:
# 768

# %%
# save length of x and y

lx, ly = face.shape

X, Y = np.ogrid[0:lx, 0:ly]

mask = (X - lx / 2) ** 2 + (Y - ly / 2) ** 2 > lx * ly / 4

# Masks
face[mask] = 0
# Fancy indexing
face[range(400), range(400)] = 255
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-f31e384708f9> in <module>
#       1 # save length of x and y
# ----> 2 lx, ly = face.shape
#       3
#       4 X, Y = np.ogrid[0:lx, 0:ly]
#       5
#
# ValueError: too many values to unpack (expected 2)

# %%
# plot a section of the racoon
plt.imshow(face[0:28, 0:28, :])

# %%
# saving shape of input image 
lx, ly = face.shape[0], face.shape[1]

# %%
# read image using scipy's misc.imread()
t = misc.imread('face.png')
# show image using imshow()
plt.imshow(t)
# Out:
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
img = face[0:28, 0:28, :]
imsave('sectionRacoon.png', arr=MxNx3)
# Out:
# /Users/ahmedacheikh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-742c20607ecc> in <module>
#       1 img = face[0:28, 0:28, :]
# ----> 2 imsave('sectionRacoon.png', arr=3)
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/utils.py in newfunc(*args, **kwds)
#      99             """`arrayrange` is deprecated, use `arange` instead!"""
#     100             warnings.warn(depdoc, DeprecationWarning, stacklevel=2)
# --> 101             return func(*args, **kwds)
#     102
#     103         newfunc = _set_function_name(newfunc, old_name)
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/misc/pilutil.py in imsave(name, arr, format)
#     215
# ...

# %%
# in a rectangle of size m x n 

# Returns count of all squares 
# in a rectangle of size m x n 
def countSquares(m, n): 
	
	# If n is smaller, swap m and n 
	if(n < m): 
		temp = m 
		m = n 
		n = temp 
		
	# Now n is greater dimension, 
	# apply formula 
	return ((m * (m + 1) * (2 * m + 1) /
		6 + (n - m) * m * (m + 1) / 2)) 

# Driver Code 
if __name__=='__main__': 
	m = 28
	n = 28
	print("Count of squares is "
		,countSquares(m, n)) 

# This code is contributed by mits.
# Out:
# Count of squares is  7714.0

# %% [markdown]
# ### Get shape

# %%
# get x and y for the new shape
x = face.shape[0] - face.shape[0]%28
y = face.shape[1] - face.shape[1]%28

resized_image = face[0:x, 0:y,:]

# %%
plt.imshow(face_resized)

# %%
plt.imshow(resized_image[0:28, 0:28, :])

# %%
plt.imshow(resized_image[28:56, 28:56, :])

# %%
for i in range()

# %%
face.shape
# Out:
# (768, 1024, 3)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

from PIL import Image
from io import BytesIO

# fig setup
fig = plt.figure(figsize=(5,5), dpi=300)
ax = fig.gca(projection='3d')
ax.set_xlim([-1,1])
ax.set_ylim([-1,1])
ax.set_zlim([-1,1])
ax.axes.xaxis.set_ticklabels([])
ax.axes.yaxis.set_ticklabels([])
ax.axes.zaxis.set_ticklabels([])

# draw a point
ax.scatter([0],[0],[0], color='b', s=200)

# %%
# save figure
# (1) save the image in memory in PNG format
png1 = BytesIO()
fig.savefig(png1, format='png')

# (2) load this image into PIL
png2 = Image.open(png1)

# (3) save as TIFF
png2.save('3dPlot.tiff')
png1.close()
